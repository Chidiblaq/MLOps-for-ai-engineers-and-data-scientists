# %%
# import library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set() # Revert to matplotlib defaults
plt.rcParams['figure.figsize']= (16, 12)

# %%
# load dataset
cleaned_df= pd.read_csv('Lagos_solocast_data_cleaned.csv')
cleaned_df.head()
# Out:
#    Unnamed: 0  MonthPE        Date  Daily_Temp  Daily_Precip  Daily_Humidity  \
# 0  2018-12-31       12  2018-12-31   29.483333     41.733333       64.083333
# 1  2019-01-01        1  2019-01-01   29.125000     26.250000       52.666667
# 2  2019-01-02        1  2019-01-02   28.675000     27.125000       54.500000
# 3  2019-01-03        1  2019-01-03   29.066667     33.766667       59.833333
# 4  2019-01-04        1  2019-01-04   29.483333     36.766667       62.666667
#
#    Daily_Pressure  Daily_WindDir  Daily_WindSpeed   Daily_DNI   Daily_DHI  \
# 0     1007.250000     205.583333         1.108333   90.083333  277.833333
# 1     1008.508333     117.500000         1.708333  260.583333  247.666667
# 2     1008.175000     180.500000         0.900000  175.083333  283.500000
# 3     1007.183333     284.916667         0.800000  159.500000  295.583333
# 4     1006.916667     280.500000         1.108333  207.166667  267.250000
#
#    Daily_radiation
# 0       342.250000
# 1       432.750000
# 2       404.833333
# 3       399.333333
# 4       414.000000

# %%
cleaned_df.describe()
# Out:
#            MonthPE   Daily_Temp  Daily_Precip  Daily_Humidity  Daily_Pressure  \
# count  1091.000000  1091.000000   1091.000000     1091.000000     1091.000000
# mean      6.496792    28.605664     49.500537       69.535969     1009.527271
# std       3.438415     1.412662      8.427000        8.672088        2.167227
# min       1.000000    24.023077      9.016667       18.666667     1003.523077
# 25%       4.000000    27.476923     45.533333       66.923077     1008.164103
# 50%       7.000000    28.975000     51.876923       69.923077     1009.441667
# 75%       9.000000    29.719231     55.400000       73.769231     1011.043910
# max      12.000000    31.376923     62.669231       92.307692     1015.575000
#
#        Daily_WindDir  Daily_WindSpeed    Daily_DNI    Daily_DHI  \
# count    1091.000000      1091.000000  1091.000000  1091.000000
# mean      218.963904         4.000068   167.650230   242.310565
# std        30.099781         1.238660   129.109800    56.303162
# min        84.000000         0.616667     0.000000    33.000000
# 25%       211.153846         3.176923    58.653846   208.875000
# 50%       225.692308         3.969231   144.416667   250.846154
# 75%       236.198718         4.900000   260.483974   283.250000
# max       290.000000         7.392308   604.769231   356.333333
#
#        Daily_radiation
# count      1091.000000
# mean        365.919050
# std         104.584349
# min          33.000000
# 25%         313.932692
# 50%         390.833333
# 75%         441.842949
# max         568.916667

# %%
cleaned_df.isnull().sum()
# Out:
# Unnamed: 0         0
# MonthPE            0
# Date               0
# Daily_Temp         0
# Daily_Precip       0
# Daily_Humidity     0
# Daily_Pressure     0
# Daily_WindDir      0
# Daily_WindSpeed    0
# Daily_DNI          0
# Daily_DHI          0
# Daily_radiation    0
# dtype: int64

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1091 entries, 0 to 1090
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1091 non-null   object
#  1   MonthPE          1091 non-null   int64
#  2   Date             1091 non-null   object
#  3   Daily_Temp       1091 non-null   float64
#  4   Daily_Precip     1091 non-null   float64
#  5   Daily_Humidity   1091 non-null   float64
#  6   Daily_Pressure   1091 non-null   float64
#  7   Daily_WindDir    1091 non-null   float64
#  8   Daily_WindSpeed  1091 non-null   float64
#  9   Daily_DNI        1091 non-null   float64
#  10  Daily_DHI        1091 non-null   float64
#  11  Daily_radiation  1091 non-null   float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 102.4+ KB

# %%
# A plot pf total irriadtion for each 
rad_vs_month= cleaned_df.loc[:, ['Daily_radiation', 'MonthPE']].groupby('MonthPE').sum()
rad_vs_month.plot()
plt.xticks(cleaned_df['MonthPE'], rotation=30)
plt.title('Monthly total solar irradiation')
plt.show()

# %%
# Daily solar irradiation plot
f, ax = plt.subplots(figsize=(20, 5))
sns.lineplot(data= cleaned_df, x="Date", y="Daily_radiation")

rad_avg= cleaned_df['Daily_radiation'].mean()
ax.axhline(rad_avg, color='green', linestyle='--', label=f"Mean - {rad_avg:.2f}")

ax.set_axisbelow(True)
ax.minorticks_on()
ax.grid(which='major', linestyle='-', linewidth=0.5, color='white',)
ax.grid(which='minor', linestyle=':', linewidth=0.5, color='white', alpha=0.7)

plt.show()
ax.legend()
# Out:
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 5996 ticks ([-54.400000000000006, ..., 1144.600000000017]), which exceeds Locator.MAXTICKS (1000).

# %%
# Histogram distribution of weather features and solar irradiation
f, ax = plt.subplots(1, 4, figsize=(20,4))
sns.histplot(cleaned_df['Daily_radiation'], stat="density", bins=30, ax=ax[0])
sns.histplot(cleaned_df['Daily_Pressure'], stat="density", bins=30, ax=ax[1])
sns.histplot(cleaned_df['Daily_Humidity'], stat="density", bins=30, ax=ax[2])
sns.histplot(cleaned_df['Daily_Temp'], stat="density", bins=30, ax=ax[3])
plt.show()

# %%
# Histogram plot of daily mean radiation
fig, ax = plt.subplots(figsize=(15, 6))
sns.barplot(x="MonthPE", y='Daily_radiation', data= cleaned_df, palette= "BuPu")
ax.set_title('Daily Mean Radiation')
plt.show()

# %%
# feature correlation
corr= cleaned_df.corr(method = "pearson")

sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap="coolwarm", square=True, annot=True, fmt=".2f")
plt.show()
# Out:
# <ipython-input-10-a249a69263a0>:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap="coolwarm", square=True, annot=True, fmt=".2f")

# %% [markdown]
# ### Statistical check: stationary or non-stationary

# %%
# Adfuller testt on target feature
from statsmodels.tsa.stattools import adfuller
Xrad = cleaned_df['Daily_radiation'].values
result = adfuller(Xrad)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value)) # p-value <= 0.05
# Out:
# ADF Statistic: -6.234097
# p-value: 0.000000
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568
